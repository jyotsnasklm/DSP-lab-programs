# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
x=np.array([[1,3],[1,2],[1,1.5],[1.5,2],[2,3],[2.5,1.5],[2,1],[3,1],[3,2],[3.5,1],[3.5,3]])
y=[0]*6+[1]*5
plt.scatter(x[:,0],x[:,1],c=y,s=50,alpha=0.9)

# %%
x=np.array([[1,3],[1,2],[1,1.5],[1.5,2],[2,3],[2.5,1.5],[2,1],[3,1],[3,2],[3.5,1],[3.5,3]])
y=[0]*6+[1]*5
svc=svm.SVC(kernel='linear').fit(x,y)
x,y=np.mgrid[0:4:200j,0:4:200j]

# %%
z=svc.decision_function(np.c_[x.ravel(),y.ravel()])
z=z.reshape(x.shape)

# %%
plt.contourf(x,y,z>0,alpha=0.4)
plt.contour(x,y,z,colors=['k'],linestyles=['-'],levels=[0])
plt.scatter(x[:,0],x[:,1],color=y,s=50,alpha=0.9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4221, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4220 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4221     colors = mcolors.to_rgba_array(c)
#    4222 except (TypeError, ValueError) as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colors.py:377, in to_rgba_array(c, alpha)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colors.py:377, in <listcomp>(.0)
#     376 else:
# --> 377     rgba = np.array([to_rgba(cc) for cc in c])
#     379 if alpha is not None:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colors.py:187, in to_rgba(c, alpha)
# ...

# %%
plt.contourf(x,y,z>0,alpha=0.4)
plt.countour(x,y,z,colors=['k','k','k'],linestyles=['--','-','---'],levels=[-1,0,1])
plt.scatter(svc.support_vectors_[:,0],vc.support_vectors_[:,1],s=120,facecolors='non')
plt.scatter(x[:,0],x[:,1],c=y,s=50,alpha=0.9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 plt.contourf(x,y,z>0,alpha=0.4)
# ----> 2 plt.countour(x,y,z,colors=['k','k','k'],linestyles=['--','-','---'],levels=[-1,0,1])
#       3 plt.scatter(svc.support_vectors_[:,0],vc.support_vectors_[:,1],s=120,facecolors='non')
#       4 plt.scatter(x[:,0],x[:,1],c=y,s=50,alpha=0.9)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'countour'
